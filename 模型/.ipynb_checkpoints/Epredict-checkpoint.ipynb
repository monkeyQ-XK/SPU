# %%
import puss
from puss import reaction_bools
from puss import single_reaction_bool
from puss import prepolymer_reaction
from puss import prepolymer_reaction_bools
#批次生成聚合物片段 
file="test.csv"
reaction_bools(file)
#批次生成预聚物
prepolymer_reaction_bools(file)

# %%
#单个预聚物
polyol=['[Re]C(COC(C)COC(COC(COC(COC(COC(COC(COC(COC(C)COC(C)COC(COC(COC(COC(COC(COC(COC(C[Re])C)C)C)C)C)C)C)C)C)C)C)C)C)C)']
Diisocyanate = ['O=C=NCCCCCCN=C=O']
prepolymer_reaction(polyol,Diisocyanate)

# %%
#单个聚合物片段
polyol =' [Re]C(COC(C)COC(COC(COC(COC(COC(COC(COC(COC(C)COC(C)COC(COC(COC(COC(COC(COC(COC(C[Re])C)C)C)C)C)C)C)C)C)C)C)C)C)C)C ' 
Diisocyanate = 'O=C=NCCCCCCN=C=O'
extender1 ='[Rn]C1=CC=C(CCC2=CC=C([Rn])C=C2)C=C1'
extender2 ='[Rn]C1=CC=C(SSC2=CC=C([Rn])C=C2)C=C1' 
single_reaction_bool(polyol,Diisocyanate,extender1,extender2)

# %%
#desptors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb  
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.model_selection import train_test_split  #分割数据集
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error   #模型评价
import warnings
warnings.filterwarnings("ignore")
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.ML.Descriptors import MoleculeDescriptors

# %%
df=pd.read_csv('460.csv')

# %%
df
# Out:
#                                                  polyol  \
# 0     [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 1     [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 2     [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 3     [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 4     [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# ...                                                 ...
# 2395  [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 2396  [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 2397  [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 2398  [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
# 2399  [Re]CCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCCCCOCC...
#
#                                Diisocyanate  \
# 0     O=C=NC1=CC=C(CC2=CC=C(N=C=O)C=C2)C=C1
# 1     O=C=NC1=CC=C(CC2=CC=C(N=C=O)C=C2)C=C1
# 2     O=C=NC1=CC=C(CC2=CC=C(N=C=O)C=C2)C=C1
# 3     O=C=NC1=CC=C(CC2=CC=C(N=C=O)C=C2)C=C1
# 4     O=C=NC1=CC=C(CC2=CC=C(N=C=O)C=C2)C=C1
# ...                                     ...
# 2395         CC1(C)CC(C)(CN=C=O)CC(N=C=O)C1
# 2396         CC1(C)CC(C)(CN=C=O)CC(N=C=O)C1
# 2397         CC1(C)CC(C)(CN=C=O)CC(N=C=O)C1
# 2398         CC1(C)CC(C)(CN=C=O)CC(N=C=O)C1
# 2399         CC1(C)CC(C)(CN=C=O)CC(N=C=O)C1
#
#                                               extender1  \
# 0                  [Rn]C1=CC=C(SSC2=CC=C([Rn])C=C2)C=C1
# 1                                        [Re]CCSSCC[Re]
# 2                                          [Rn]CSSC[Rn]
# 3                      [Rn]C(C(OC)=O)CSSCC(C(OC)=O)[Rn]
# 4                  [Re]C1=CC=C(SSC2=CC=C([Re])C=C2)C=C1
# ...                                                 ...
# 2395                                   [Re]CCCSSCCC[Re]
# 2396                   [Rn]C(C(OC)=O)CSSCC(C(OC)=O)[Rn]
# 2397  [Re]CCOC(C1=C(C=CC=C1)SSC2=CC=CC=C2C(OCC[Re])=...
# 2398  O=C(OCCCC[Re])C1=CC=CC=C1SSC(C=CC=C2)=C2C(OCCC...
# 2399  O=C(OCCCCCC[Re])C1=CC=CC=C1SSC(C=CC=C2)=C2C(OC...
#
#                       extender2  \
# 0                  [Re]CCCC[Re]
# 1                  [Re]CCCC[Re]
# 2                  [Re]CCCC[Re]
# 3                  [Re]CCCC[Re]
# 4                  [Re]CCCC[Re]
# ...                         ...
# 2395  O=C1N=C([N])NC(C)=C1CC[O]
# 2396  O=C1N=C([N])NC(C)=C1CC[O]
# 2397  O=C1N=C([N])NC(C)=C1CC[O]
# 2398  O=C1N=C([N])NC(C)=C1CC[O]
# 2399  O=C1N=C([N])NC(C)=C1CC[O]
#
#                                            polymer-unit  \
# 0     CNC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 1     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 2     CNC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 3     CNC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 4     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# ...                                                 ...
# 2395  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2396  CNC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2397  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2398  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2399  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
#
#                                              prepolymer  \
# 0     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 1     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 2     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 3     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# 4     COC(=O)Nc1ccc(Cc2ccc(NC(=O)OCCCCOCCCCOCCCCOCCC...
# ...                                                 ...
# 2395  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2396  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2397  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2398  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
# 2399  COC(=O)NC1CC(C)(C)CC(C)(CNC(=O)OCCCCOCCCCOCCCC...
#
#                                         extender1append  \
# 0                        NC1=CC=C(SSC2=CC=C(N)C=C2)C=C1
# 1                                              OCCSSCCO
# 2                                                NCSSCN
# 3                            NC(C(OC)=O)CSSCC(C(OC)=O)N
# 4                        OC1=CC=C(SSC2=CC=C(O)C=C2)C=C1
# ...                                                 ...
# 2395                                         OCCCSSCCCO
# 2396                         NC(C(OC)=O)CSSCC(C(OC)=O)N
# 2397       OCCOC(C1=C(C=CC=C1)SSC2=CC=CC=C2C(OCCO)=O)=O
# 2398   O=C(OCCCCO)C1=CC=CC=C1SSC(C=CC=C2)=C2C(OCCCCO)=O
# 2399  O=C(OCCCCCCO)C1=CC=CC=C1SSC(C=CC=C2)=C2C(OCCCC...
#
#             extender2append  polol_mw  polyol_ratio  Diisocyanate_ratio  \
# 0                    OCCCCO      2000          0.25                 0.5
# 1                    OCCCCO      2000          0.25                 0.5
# 2                    OCCCCO      2000          0.25                 0.5
# 3                    OCCCCO      2000          0.25                 0.5
# 4                    OCCCCO      2000          0.25                 0.5
# ...                     ...       ...           ...                 ...
# 2395  O=C1N=C(N)NC(C)=C1CCO      1000          0.25                 0.5
# 2396  O=C1N=C(N)NC(C)=C1CCO      1000          0.25                 0.5
# 2397  O=C1N=C(N)NC(C)=C1CCO      1000          0.25                 0.5
# 2398  O=C1N=C(N)NC(C)=C1CCO      1000          0.25                 0.5
# 2399  O=C1N=C(N)NC(C)=C1CCO      1000          0.25                 0.5
#
#       extender1_ratio  extender2_ratio    di_mw   ex1_mw   ex2_mw
# 0              0.2500           0.0000  250.257  248.376   90.122
# 1              0.2500           0.0000  250.257  154.256   90.122
# 2              0.2500           0.0000  250.257  124.234   90.122
# 3              0.2500           0.0000  250.257  268.360   90.122
# 4              0.2500           0.0000  250.257  250.344   90.122
# ...               ...              ...      ...      ...      ...
# 2395           0.0625           0.1875  222.288  182.310  169.184
# 2396           0.0625           0.1875  222.288  268.360  169.184
# 2397           0.0625           0.1875  222.288  394.470  169.184
# 2398           0.0625           0.1875  222.288  450.578  169.184
# 2399           0.0625           0.1875  222.288  506.686  169.184
#
# [2400 rows x 16 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb  
from sklearn.preprocessing import PolynomialFeatures,StandardScaler
from sklearn.model_selection import train_test_split  #分割数据集
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error   #模型评价
import warnings
warnings.filterwarnings("ignore")
from rdkit import Chem
from rdkit.Chem import Descriptors
from rdkit.ML.Descriptors import MoleculeDescriptors

# %%
df=pd.read_csv('test.csv')
smiles = df.iloc[:,5]
mw=[]
for  smile in smiles:
    mol = Chem.MolFromSmiles(smile)
    # 计算分子的相对分子质量
    mol_weight = Descriptors.MolWt(mol)
    mw.append(mol_weight)
df['ex2_mw']=mw 
df.to_csv('test.csv', index=False)

# %%
dataset=pd.read_csv('smiles1.csv')
smiles = dataset.iloc[:,7] # 获取分子的 SMILES表达式


# get the name of calculated discriptors
descriptor_names = []
for descriptor_information in Descriptors.descList:
    descriptor_names.append(descriptor_information[0]) # 第一列列名
print("The num of descriptors:", len(descriptor_names))

# calculate
descriptors = []
descriptor_calculator = MoleculeDescriptors.MolecularDescriptorCalculator(descriptor_names)
print("num of molcular:%d" % len(smiles))
for index, smiles_i in enumerate(smiles):
    # print(index + 1, '/' ,len(smiles))
    molecule = Chem.MolFromSmiles(smiles_i)
    descriptors.append(descriptor_calculator.CalcDescriptors(molecule))
descriptors1=[]    
for descriptor in descriptor_names:
    descriptor='piece'+descriptor
    descriptors1.append(descriptor)
    
    
descriptors = pd.DataFrame(descriptors, index = dataset.index, columns = descriptors1)


descriptors.to_csv('piece_rdkit.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dataset=pd.read_csv('smiles1.csv')
#       2 smiles = dataset.iloc[:,7] # 获取分子的 SMILES表达式
#       5 # get the name of calculated discriptors
#
# File E:\ana\envs\pu\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File E:\ana\envs\pu\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File E:\ana\envs\pu\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File E:\ana\envs\pu\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File E:\ana\envs\pu\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'smiles1.csv'

# %%
#dataset=pd.read_csv('test.csv')
smiles = df.iloc[:,4]
descriptor_names = ['VSA_EState6','BCUT2D_MRHI','EState_VSA6','PEOE_VSA10','fr_C_O_noCOO','SlogP_VSA5','BertzCT','EState_VSA1','SMR_VSA5','VSA_EState4','PEOE_VSA7','FpDensityMorgan2'
,'EState_VSA2','BCUT2D_CHGLO','HallKierAlpha','BCUT2D_LOGPHI','MaxEStateIndex','BCUT2D_MWHI','Chi4n','SlogP_VSA3','VSA_EState3','VSA_EState9','VSA_EState2','MinAbsEStateIndex','Chi4v','NumHeteroatoms','Chi3v','Kappa3','MinEStateIndex','PEOE_VSA14','EState_VSA3','VSA_EState5','PEOE_VSA8','BCUT2D_CHGHI'
]
#for descriptor_information in descriptor_names:
    #descriptor_names.append(descriptor_information[0]) # 第一列列名
print("The num of descriptors:", len(descriptor_names))
descriptors = []
descriptor_calculator = MoleculeDescriptors.MolecularDescriptorCalculator(descriptor_names)
print("num of molcular:%d" % len(smiles))
for index, smiles_i in enumerate(smiles):
    # print(index + 1, '/' ,len(smiles))
    molecule = Chem.MolFromSmiles(smiles_i)
    descriptors.append(descriptor_calculator.CalcDescriptors(molecule))
descriptors1=[]    
for descriptor in descriptor_names:
    descriptor='piece'+descriptor
    descriptors1.append(descriptor)
    
    
descriptors1 = pd.DataFrame(descriptors, columns = descriptors1)
descriptors5= pd.DataFrame(descriptors1)
descriptors5
# Out:
# The num of descriptors: 34
# num of molcular:2400

# %%
#dataset=pd.read_csv('test.csv')
smiles = df.iloc[:,6]
descriptor_names = ['EState_VSA8',
'qed',
'SPS.1',
'PEOE_VSA8',
'EState_VSA4','BCUT2D_LOGPHI'
]
#for descriptor_information in Descriptors.descList:
   # descriptor_names.append(descriptor_information[0]) # 第一列列名
print("The num of descriptors:", len(descriptor_names))
descriptors = []
descriptor_calculator = MoleculeDescriptors.MolecularDescriptorCalculator(descriptor_names)
print("num of molcular:%d" % len(smiles))
for index, smiles_i in enumerate(smiles):
    # print(index + 1, '/' ,len(smiles))
    molecule = Chem.MolFromSmiles(smiles_i)
    descriptors.append(descriptor_calculator.CalcDescriptors(molecule))
descriptors1=[]    
for descriptor in descriptor_names:
    descriptor='ex1'+descriptor
    descriptors1.append(descriptor)
    
    
descriptors2 = pd.DataFrame(descriptors, columns = descriptors1)
descriptors2= pd.DataFrame(descriptors2)
descriptors2

# %%
#dataset=pd.read_csv('test.csv')
smiles = df.iloc[:,7]
descriptor_names = ['MolLogP',
'Chi4n',
'MinAbsEStateIndex',
'BCUT2D_LOGPHI']
#for descriptor_information in Descriptors.descList:
   # descriptor_names.append(descriptor_information[0]) # 第一列列名
print("The num of descriptors:", len(descriptor_names))
descriptors = []
descriptor_calculator = MoleculeDescriptors.MolecularDescriptorCalculator(descriptor_names)
print("num of molcular:%d" % len(smiles))
for index, smiles_i in enumerate(smiles):
    # print(index + 1, '/' ,len(smiles))
    molecule = Chem.MolFromSmiles(smiles_i)
    descriptors.append(descriptor_calculator.CalcDescriptors(molecule))
descriptors1=[]    
for descriptor in descriptor_names:
    descriptor='ex2'+descriptor
    descriptors1.append(descriptor)
    
    
descriptors3 = pd.DataFrame(descriptors, columns = descriptors1)
descriptors3= pd.DataFrame(descriptors3)
descriptors3
# Out:
# The num of descriptors: 4
# num of molcular:6
#    ex2MolLogP  ex2Chi4n  ex2MinAbsEStateIndex  ex2BCUT2D_LOGPHI
# 0     -0.2488  0.223607                 0.195          1.802227
# 1     -0.2488  0.223607                 0.195          1.802227
# 2     -0.2488  0.223607                 0.195          1.802227
# 3     -0.2488  0.223607                 0.195          1.802227
# 4     -0.2488  0.223607                 0.195          1.802227
# 5     -0.2488  0.223607                 0.195          1.802227

# %%
dataset=pd.read_csv('test.csv')
smiles = dataset.iloc[:,7]
descriptor_names = ['Chi1n','Chi4v'
,'MinEStateIndex',
'Chi4n',
'SMR_VSA6',
'Kappa3',
'MaxPartialCharge',
'PEOE_VSA8'
]
#for descriptor_information in Descriptors.descList:
   # descriptor_names.append(descriptor_information[0]) # 第一列列名
print("The num of descriptors:", len(descriptor_names))
descriptors = []
descriptor_calculator = MoleculeDescriptors.MolecularDescriptorCalculator(descriptor_names)
print("num of molcular:%d" % len(smiles))
for index, smiles_i in enumerate(smiles):
    # print(index + 1, '/' ,len(smiles))
    molecule = Chem.MolFromSmiles(smiles_i)
    descriptors.append(descriptor_calculator.CalcDescriptors(molecule))
descriptors1=[]    
for descriptor in descriptor_names:
    descriptor='pre'+descriptor
    descriptors1.append(descriptor)
    
    
descriptors4 = pd.DataFrame(descriptors, columns = descriptors1)
descriptors4= pd.DataFrame(descriptors4)
descriptors4
#descriptors=pd.concat([descriptors5,descriptors2,descriptors3,descriptors4],axis=1)
#descriptors
# Out:
# The num of descriptors: 8
# num of molcular:6
#     preChi1n   preChi4v  preMinEStateIndex   preChi4n  preSMR_VSA6  preKappa3  \
# 0  42.232076  11.108652           -0.50448  11.108652   220.479445    61.5019
# 1  42.232076  11.108652           -0.50448  11.108652   220.479445    61.5019
# 2  42.232076  11.108652           -0.50448  11.108652   220.479445    61.5019
# 3  42.232076  11.108652           -0.50448  11.108652   220.479445    61.5019
# 4  42.232076  11.108652           -0.50448  11.108652   220.479445    61.5019
# 5  42.232076  11.108652           -0.50448  11.108652   220.479445    61.5019
#
#    preMaxPartialCharge  prePEOE_VSA8
# 0             0.411112    194.528476
# 1             0.411112    194.528476
# 2             0.411112    194.528476
# 3             0.411112    194.528476
# 4             0.411112    194.528476
# 5             0.411112    194.528476

# %%
data={'R': [1], 
      'polyol_ratio':[2],
      'Diisocyanate_ratio':[3],
      'Hs_wt':[4], 
      'extender2_ratio':[5],
      'extender1_ratio':[6], 
      'self_time':[7],
      'self_tem':[8], 
      'E1':[9]}
data=pd.DataFrame(data)
descriptors=pd.concat([descriptors5,descriptors2,descriptors3,descriptors4,data],axis=1)

# %%
column_order = [ 'pieceVSA_EState6', 'pieceBCUT2D_MRHI', 'ex1EState_VSA8',
       'pieceEState_VSA6', 'piecePEOE_VSA10', 'piecefr_C_O_noCOO',
       'pieceSlogP_VSA5', 'pieceBertzCT', 'pieceEState_VSA1', 'ex1qed',
       'preChi1n', 'pieceSMR_VSA5', 'ex2MolLogP', 'ex1BCUT2D_LOGPHI',
       'pieceVSA_EState4', 'preChi4v', 'piecePEOE_VSA7', 'ex2Chi4n',
       'pieceFpDensityMorgan2', 'ex1SPS.1', 'preMinEStateIndex',
       'pieceEState_VSA2', 'pieceBCUT2D_CHGLO', 'pieceHallKierAlpha',
       'pieceBCUT2D_LOGPHI', 'pieceMaxEStateIndex', 'pieceBCUT2D_MWHI',
       'ex1PEOE_VSA8', 'ex2MinAbsEStateIndex', 'preChi4n', 'pieceChi4n',
       'pieceSlogP_VSA3', 'preSMR_VSA6', 'ex1EState_VSA4', 'R',
       'pieceVSA_EState3', 'ex2BCUT2D_LOGPHI', 'pieceVSA_EState9',
       'pieceVSA_EState2', 'pieceMinAbsEStateIndex', 'pieceChi4v',
       'pieceNumHeteroatoms', 'pieceChi3v', 'preKappa3', 'polyol_ratio',
       'preMaxPartialCharge', 'pieceKappa3', 'Diisocyanate_ratio',
       'pieceMinEStateIndex', 'piecePEOE_VSA14', 'pieceEState_VSA3',
       'pieceVSA_EState5', 'piecePEOE_VSA8', 'pieceBCUT2D_CHGHI', 'Hs_wt',
       'extender2_ratio', 'prePEOE_VSA8', 'extender1_ratio', 'self_time',
       'self_tem', 'E1']


# 按照指定的列名重新索引DataFrame的列顺序
df = descriptors[column_order]

# %%
df.to_csv('a.csv')
